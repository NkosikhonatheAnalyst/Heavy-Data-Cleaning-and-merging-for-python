# %%
#IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
#WE INSERT THE FIRST EXCEL WORKSHEET(SALES DATA) WHICH WAS HAVING TWO TABLES ON IT, NOW WHEN I INSERTED THEM THEY COMBINED AUTOMATILY, 
#BUT THE DATA NOW WILL REQUIRE A VERY HEAVY CLEANING BECAUSE IT DOESTN'T LOOK NICE NOW.

# %%
df1 = pd.read_excel(r"G:\Python Pandas,Jupyter\combine-tables.xlsx" , sheet_name= 'Sales Data')
df1
# Out:
#      Unnamed: 0  Unnamed: 1 Combine Two Excel Tables   Unnamed: 3  \
# 0           NaN         NaN                      NaN          NaN
# 1           NaN         NaN                      NaN          NaN
# 2           NaN         NaN                      NaN          NaN
# 3           NaN         NaN             Sales Person    Geography
# 4           NaN         NaN           Curtice Advani    Australia
# ..          ...         ...                      ...          ...
# 353         NaN         NaN              Van Tuxwell        India
# 354         NaN         NaN      Rafaelita Blaksland    Australia
# 355         NaN         NaN            Kelci Walkden    Australia
# 356         NaN         NaN          Gunar Cockshoot  New Zealand
# 357         NaN         NaN           Mallorie Waber          USA
#
#               Unnamed: 4           Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                    NaN                  NaN        NaN        NaN
# ...

# %%
#NOW WE INSERT ANOTHER WORKSHEET(MAPPING TABLES) WHICH GOT TWO TABLES AGAIN, AND THE DATA IS VERY BAD, WE NEED TO DO A VERY HEAVY CLEANING AS WELL.

# %%
df2 = pd.read_excel(r"G:\Python Pandas,Jupyter\combine-tables.xlsx" , sheet_name= 'Mapping tables')
df2
# Out:
#     Unnamed: 0  Unnamed: 1      Table to Combine Unnamed: 3 Unnamed: 4  \
# 0          NaN         NaN                   NaN        NaN        NaN
# 1          NaN         NaN                   NaN        NaN        NaN
# 2          NaN         NaN               Product   Category       Size
# 3          NaN         NaN             Milk Bars       Bars      LARGE
# 4          NaN         NaN        50% Dark Bites      Bites      LARGE
# 5          NaN         NaN          Almond Choco       Bars      LARGE
# 6          NaN         NaN       Raspberry Choco       Bars      LARGE
# 7          NaN         NaN       Mint Chip Choco       Bars      LARGE
# 8          NaN         NaN               Eclairs      Bites      LARGE
# 9          NaN         NaN         Drinking Coco      Other      LARGE
# 10         NaN         NaN       99% Dark & Pure       Bars      LARGE
# 11         NaN         NaN          Orange Choco       Bars      LARGE
# ...

# %%
#DATA FRAME ONE WHO IS THE FIRST WORKSHEET, THE FIRST THING WE DOING IS TO REMOVE THE EMPTY COLUMNS.

# %%
df1.drop(columns= ['Unnamed: 10','Unnamed: 0','Unnamed: 1', 'Unnamed: 11'], inplace=True)

# %%
#AND NEXT WE REMOVE,EMPTY ROWS.

# %%
df1.drop([0,1], inplace=True)

# %%
#WE WANT TO SEE THE COLUMNS WE HAVE ON DATA FRAME 1

# %%
df1.columns
# Out:
# Index(['Combine Two Excel Tables', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
#NOW WE ARE RENAMING ALL THE COLUMNS.

# %%
df1.rename(columns= {'Combine Two Excel Tables':'Sales Person', 'Unnamed: 3':'Geography','Unnamed: 4':'Product', 'Unnamed: 5':'Date',
                     'Unnamed: 6':'Amount','Unnamed: 7':'Boxes','Unnamed: 8':'Category','Unnamed: 9':'Size'},inplace=True)
df1
# Out:
#             Sales Person    Geography              Product  \
# 4         Curtice Advani    Australia          After Nines
# 5         Andria Kimpton    Australia   Manuka Honey Choco
# 6    Dennison Crosswaite          USA         Orange Choco
# 7          Kelci Walkden           UK  Spicy Special Slims
# 8           Ches Bonnell       Canada      99% Dark & Pure
# ..                   ...          ...                  ...
# 353          Van Tuxwell        India        Drinking Coco
# 354  Rafaelita Blaksland    Australia      Mint Chip Choco
# 355        Kelci Walkden    Australia  Spicy Special Slims
# 356      Gunar Cockshoot  New Zealand      Mint Chip Choco
# 357       Mallorie Waber          USA  Spicy Special Slims
#
#                     Date  Amount  Boxes Category   Size
# 4    2022-01-24 00:00:00    1113     70    Bites  LARGE
# 5    2022-01-11 00:00:00    6699    609    Other  SMALL
# 6    2022-01-14 00:00:00    7805    488     Bars  LARGE
# ...

# %%
#AFTER RENAMING WE REMOVE ROW THREE, WHICH WAS THE ONE THAT WAS HAVING THE ORIGINAL COLUMNS NAMES.

# %%
df1.drop([3], inplace=True)
df1
# Out:
#             Sales Person    Geography              Product  \
# 4         Curtice Advani    Australia          After Nines
# 5         Andria Kimpton    Australia   Manuka Honey Choco
# 6    Dennison Crosswaite          USA         Orange Choco
# 7          Kelci Walkden           UK  Spicy Special Slims
# 8           Ches Bonnell       Canada      99% Dark & Pure
# ..                   ...          ...                  ...
# 353          Van Tuxwell        India        Drinking Coco
# 354  Rafaelita Blaksland    Australia      Mint Chip Choco
# 355        Kelci Walkden    Australia  Spicy Special Slims
# 356      Gunar Cockshoot  New Zealand      Mint Chip Choco
# 357       Mallorie Waber          USA  Spicy Special Slims
#
#                     Date Amount Boxes Category   Size
# 4    2022-01-24 00:00:00   1113    70    Bites  LARGE
# 5    2022-01-11 00:00:00   6699   609    Other  SMALL
# 6    2022-01-14 00:00:00   7805   488     Bars  LARGE
# ...

# %%
#WE WANT TO SEE IF WE HAVE ANY MISSING VALUES, AND DUPLICATED, BUT WE SEEM TO HAVE NO MISSING VALUE OR EVEN DUPLICATED

# %%
df1.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df1.duplicated().sum().sum()
# Out:
# np.int64(0)

# %%
#NOW WE WANT TO SEE THE INFORMATION ABOUT DATA FRAME 1, TO SEE IF WE GOT COLUMNS THAT WE NEED TO CONVERT TO CHANGE DATA TYPE.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 4 to 357
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sales Person  354 non-null    object
#  1   Geography     354 non-null    object
#  2   Product       354 non-null    object
#  3   Date          354 non-null    object
#  4   Amount        354 non-null    object
#  5   Boxes         354 non-null    object
#  6   Category      354 non-null    object
#  7   Size          354 non-null    object
# dtypes: object(8)
# memory usage: 22.3+ KB

# %%
#BELOW, WE ARE CHANGING THESE TWO COLUMNS 'AMOUNT' AND 'BOXES' INTO INTERGERS.

# %%
df1['Amount'] = df1['Amount'].astype('int')

# %%
df1['Boxes'] = df1['Boxes'].astype('int')

# %%
#NOW IF WE CHECK THEY ARE CHANGED.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 4 to 357
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sales Person  354 non-null    object
#  1   Geography     354 non-null    object
#  2   Product       354 non-null    object
#  3   Date          354 non-null    object
#  4   Amount        354 non-null    int64
#  5   Boxes         354 non-null    int64
#  6   Category      354 non-null    object
#  7   Size          354 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 22.3+ KB

# %%
#NOW WE LOOKING AT DATA FRAME 2, WE WANT TO REMOVE THE EMPTY COLUMNS, AND THE EXTRA COLUMNS.

# %%
df2.drop(columns= ['Unnamed: 0','Unnamed: 1','Unnamed: 6','Unnamed: 7'], inplace=True)
df2
# Out:
#         Table to Combine Unnamed: 3 Unnamed: 4    Unnamed: 5  \
# 0                    NaN        NaN        NaN           NaN
# 1                    NaN        NaN        NaN           NaN
# 2                Product   Category       Size  Cost per Box
# 3              Milk Bars       Bars      LARGE        1.8652
# 4         50% Dark Bites      Bites      LARGE           2.8
# 5           Almond Choco       Bars      LARGE       13.3485
# 6        Raspberry Choco       Bars      LARGE        6.0983
# 7        Mint Chip Choco       Bars      LARGE        2.2656
# 8                Eclairs      Bites      LARGE        2.8195
# 9          Drinking Coco      Other      LARGE        2.4774
# 10       99% Dark & Pure       Bars      LARGE        4.6592
# 11          Orange Choco       Bars      LARGE         8.787
# 12   Spicy Special Slims      Bites      LARGE        9.2086
# 13           After Nines      Bites      LARGE        6.3416
# ...

# %%
#WE WANT TO SEE ALL THE COLUMNS WE HAVE ON DATA FRAME 2.

# %%
df2.columns
# Out:
# Index(['Table to Combine', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
#NOW WE CAN CHANGE THE COLUMNS NAMES.

# %%
df2.rename(columns= {'Table to Combine': 'Product', 'Unnamed: 3':'Category','Unnamed: 4' :'Size','Unnamed: 5':'Cost per Box',
                     'Unnamed: 8': 'Sales Person','Unnamed: 9':'Team','Unnamed: 10':'Office', 'Unnamed: 11':'Commission %'},inplace=True)
df2
# Out:
#                  Product  Category   Size  Cost per Box         Sales Person  \
# 0                    NaN       NaN    NaN           NaN                  NaN
# 1                    NaN       NaN    NaN           NaN                  NaN
# 2                Product  Category   Size  Cost per Box         Sales person
# 3              Milk Bars      Bars  LARGE        1.8652         Barr Faughny
# 4         50% Dark Bites     Bites  LARGE           2.8  Dennison Crosswaite
# 5           Almond Choco      Bars  LARGE       13.3485      Gunar Cockshoot
# 6        Raspberry Choco      Bars  LARGE        6.0983       Wilone O'Kielt
# 7        Mint Chip Choco      Bars  LARGE        2.2656         Gigi Bohling
# 8                Eclairs     Bites  LARGE        2.8195       Curtice Advani
# 9          Drinking Coco     Other  LARGE        2.4774          Kaine Padly
# 10       99% Dark & Pure      Bars  LARGE        4.6592         Ches Bonnell
# ...

# %%
#NOW WE REMOVING FROM ROW INDEX 0, 1 AND 2.

# %%
df2.drop([0,1,2],inplace=True)
df2
# Out:
#                  Product Category   Size Cost per Box         Sales Person  \
# 3              Milk Bars     Bars  LARGE       1.8652         Barr Faughny
# 4         50% Dark Bites    Bites  LARGE          2.8  Dennison Crosswaite
# 5           Almond Choco     Bars  LARGE      13.3485      Gunar Cockshoot
# 6        Raspberry Choco     Bars  LARGE       6.0983       Wilone O'Kielt
# 7        Mint Chip Choco     Bars  LARGE       2.2656         Gigi Bohling
# 8                Eclairs    Bites  LARGE       2.8195       Curtice Advani
# 9          Drinking Coco    Other  LARGE       2.4774          Kaine Padly
# 10       99% Dark & Pure     Bars  LARGE       4.6592         Ches Bonnell
# 11          Orange Choco     Bars  LARGE        8.787       Andria Kimpton
# 12   Spicy Special Slims    Bites  LARGE       9.2086          Brien Boise
# 13           After Nines    Bites  LARGE       6.3416         Husein Augar
# ...

# %%
#NOW IT IS EASY FOR US TO MERGE THE TWO DATA SETS, AND WE CALL IT DATA FRAME 4.

# %%
df4 = df1.merge(df2)

# %%
#BELOW IS THE COMBINED DATA SET.

# %%
df4
# Out:
#            Sales Person    Geography               Product  \
# 0          Ches Bonnell       Canada       99% Dark & Pure
# 1       Madelene Upcott       Canada    Manuka Honey Choco
# 2           Brien Boise       Canada   Spicy Special Slims
# 3        Dotty Strutley           UK            White Choc
# 4        Dotty Strutley          USA            White Choc
# 5       Madelene Upcott           UK    Manuka Honey Choco
# 6        Andria Kimpton           UK          Orange Choco
# 7       Madelene Upcott    Australia    Manuka Honey Choco
# 8        Mallorie Waber       Canada  Choco Coated Almonds
# 9       Madelene Upcott  New Zealand    Manuka Honey Choco
# 10     Karlen McCaffrey       Canada      Fruit & Nut Bars
# 11       Wilone O'Kielt          USA       Raspberry Choco
# 12  Dennison Crosswaite           UK        50% Dark Bites
#
#                    Date  Amount  Boxes Category   Size Cost per Box     Team  \
# ...

# %%
#LET SEE THE INFORMATION ABOUT DATA FRAME 4 OUR COMBINED DATA, WE WANT TO SEE IF WE DONT HAVE ANY COLUMN THAT WE NEED TO CONVERT 
#TO A DIFFEENT DATA SET.

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sales Person  13 non-null     object
#  1   Geography     13 non-null     object
#  2   Product       13 non-null     object
#  3   Date          13 non-null     object
#  4   Amount        13 non-null     int64
#  5   Boxes         13 non-null     int64
#  6   Category      13 non-null     object
#  7   Size          13 non-null     object
#  8   Cost per Box  13 non-null     object
#  9   Team          13 non-null     object
#  10  Office        13 non-null     object
#  11  Commission %  13 non-null     object
# dtypes: int64(2), object(10)
# memory usage: 1.3+ KB

# %%
#WE ARE CONVERTING TWO COLUMNS TO FLOAT BECAUSE THEY ARE DECIMALS.

# %%
df4['Cost per Box']= df4['Cost per Box'].astype('float') 
df4['Commission %']= df4['Commission %'].astype('float')

# %%
#NOW WE CAN SEE BELOW ALL THE COLUMNS ARE IN THE RIGHT DATA TYPES.
#NOW WE CAN SAY OUR DATA IS CLEANED, OUR PROJECT IS DONE.

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sales Person  13 non-null     object
#  1   Geography     13 non-null     object
#  2   Product       13 non-null     object
#  3   Date          13 non-null     object
#  4   Amount        13 non-null     int64
#  5   Boxes         13 non-null     int64
#  6   Category      13 non-null     object
#  7   Size          13 non-null     object
#  8   Cost per Box  13 non-null     float64
#  9   Team          13 non-null     object
#  10  Office        13 non-null     object
#  11  Commission %  13 non-null     float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.3+ KB
